# %% [markdown]
# # PROJECT OBJECTIVES

# %% [raw]
# 1.	The aim of the project is to predict fraudulent credit card transactions using machine learning models.
# 2.	Fraud detection, and its prevention is crucial from the bank’s as well as customer’s perspective.
# 3.	Banks cannot afford to lose the customers’ money to fraudsters.
# 4.	Every fraud is a loss to the bank, and the bank is responsible for fraudulent transactions.
#
# The ultimate goal is to uphold the reputation of the bank, and to ensure that its clients remain protected.

# %% [markdown]
# #### STEPS INVOLVED IN CREDIT CARD FRAUD PREVENTION

# %% [raw]
# 1.	Reading, understanding, and visualizing the data.
# 2.	Preparing the model for modelling.
# 3.	Building the model.
# 4.	Evaluating the model.

# %%
# Importing important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# #### READING AND ANALYZING THE DATA

# %%
# Reading the imported data
full_data = pd.read_csv('C:/Users/Mayur Mitra/Documents/InLight Tech/creditcard.csv')

# %%
# View in the 'Head' of the dataset
full_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Obtaining the size of the dataset - Rows and Columns
full_data.shape
# Out:
# (284807, 31)

# %%
# Obtaining detailed information about the attributes of the dataset
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Obtaining some statistical details about the dataset
full_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# #### HANDLING MISSING VALUES IN THE DATASET

# %%
# Check for missing values in each of the columns.
data_missing_attributes = (round((full_data.isnull().sum()/len(full_data.index))*100,2).to_frame('null')).sort_values('null',ascending=False)
data_missing_attributes
# Out:
#         null
# Time     0.0
# V1       0.0
# V2       0.0
# V3       0.0
# V4       0.0
# V5       0.0
# V6       0.0
# V7       0.0
# V8       0.0
# V9       0.0
# V10      0.0
# V11      0.0
# V12      0.0
# V13      0.0
# V14      0.0
# V15      0.0
# V16      0.0
# V17      0.0
# V18      0.0
# V19      0.0
# V20      0.0
# V21      0.0
# V22      0.0
# V23      0.0
# V24      0.0
# V25      0.0
# V26      0.0
# V27      0.0
# V28      0.0
# Amount   0.0
# Class    0.0

# %% [raw]
# From the above analysis, we can see that there is no missing values in any of the columns.
# Thus, there is no problem with null values in the entire dataset.

# %% [markdown]
# #### CHECKING THE DISTRIBUTION OF THE ATTRIBUTE - CLASS COLUMN

# %%
# To obtain count of the number of unique values in the column 'Class' of the database
classes = full_data['Class'].value_counts()
classes
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [raw]
# In the 'creditcard.csv' dataset, the column 'Class' is the Target variable.
# Class = 0, means legitimate or non-fraud tranasactions.
# Class = 1, means fraud transactions.
# From the value_counts of the 'Class' column, it can be seen that there are:-
# a.) 284315 legitimate transactions.
# b.) 492 fraud transactions.

# %%
# To obtain the percentage of Legitimate Transactions
legitimate = round((classes[0]/full_data['Class'].count()*100),2)
legitimate_percentage = f"{legitimate}%"
legitimate_percentage
# Out:
# '99.83%'

# %%
# To obtain the percentage of Fraud Transactions
fraud = round((classes[1]/full_data['Class'].count()*100),2)
fraud_percentage = f"{fraud}%"
fraud_percentage
# Out:
# '0.17%'

# %% [raw]
# Thus, it is found that only 0.17% of the dataset is fraudulent as per 'Class' attribute.

# %%
# Comparing Legitimate vs. Fraud transactions as per Class using Bar Plot
sb.countplot(x='Class', data=full_data)
plt.title("Number of Legitimate Vs. Fraud transactions")
plt.show()

# %%
# Comparing Legitimate Vs. Fraud transactions as a Percentage

legitimate = round((classes[0]/full_data['Class'].count()*100),2)
legitimate_percentage = f"{legitimate}%"

fraud = round((classes[1]/full_data['Class'].count()*100),2)
fraud_percentage = f"{fraud}%"

fraud_percentage_dict = {
    'Class':['Fraudulent','Legitimate'], 
    'Percentage':[legitimate_percentage,fraud_percentage]
}
full_data_fraud_percentage = pd.DataFrame(fraud_percentage_dict)
sb.barplot(x='Class',y='Percentage', data=full_data_fraud_percentage)
plt.title("Percentage of Legitimate vs.Fraudulent Transaction")

plt.show()

# %% [markdown]
# ### TREATMENT OF OUTLIER

# %% [raw]
# No outlier treatment for this particular dataset is done because all of the columns are already PCA transformed, which assumed that the outlier values are taken care while transforming the data.

# %% [markdown]
# #### DISTRIBUTION OF CLASS WITH RESPECT TO TIME

# %%
# Creating Legitimate dataframe
data_legitimate = full_data[full_data['Class']==0]

# Creating Fraud dataframe
data_fraud = full_data[full_data['Class']==1]

# %%
# Distribution Plot of Legitimate Vs. Fraud Transaction w.r.t. Time
plt.figure(figsize=(8,5))
ax = sb.distplot(data_fraud['Time'],label='fraudulent',hist=False)
ax = sb.distplot(data_legitimate['Time'],label='legitimate',hist=False)
ax.set(xlabel='Time (in seconds) elapsed between the first transaction and consecutive transactions')
plt.show()

# %% [raw]
# OBSERVATION
# There is no specific pattern for the legitimate transactions and fraud transactions with respect to 'Time'.
# Thus, the 'Time' column can be dropped.

# %%
# Dropping the 'Time' column
full_data.drop('Time', axis=1, inplace=True)

# %% [markdown]
# #### DISTRIBUTION OF CLASS WITH RESPECT TO AMOUNT

# %%
# Distribution Plot of Legitimate Vs. Fraud Transaction w.r.t. Amount
plt.figure(figsize=(8,5))
ax = sb.distplot(data_fraud['Amount'],label='fraudulent',hist=False)
ax = sb.distplot(data_legitimate['Time'],label='legitimate',hist=False)
ax.set(xlabel='Transaction Amount')
plt.show()

# %% [raw]
# OBSERVATION
# From the above distribution plot, it is clear that most of the frauds are concentrated in the lower range of amounts.
# The legitimate transactions are spread from low to high.

# %% [markdown]
# ### SPLITTING THE DATASET INTO TRAIN DATA & TEST DATA

# %%
# Importing the 'Train-Test-Split' from Scikit Learn
from sklearn.model_selection import train_test_split

# Putting 'Feature' variables into X axis data
X = full_data.drop(['Class'],axis=1)

# Putting 'Target' variable into Y axis data
Y = full_data['Class']

# Splitting the data into Training data and Testing data
# Training Data = 75%
# Testing Data = 25%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=200)

# %% [markdown]
# #### FEATURE SCALING

# %% [raw]
# Scaling on the 'Amount' attribute/column because all the other columns have already been scaled by Pricipal Component Analysis (PCA) transformation.

# %% [markdown]
# #### SCALING & TRANSFORMING - TRAINING DATA

# %%
# Importing the 'Preprocessing' library for standardization.
from sklearn.preprocessing import StandardScaler

# Representing the 'Standard Scaler' by 'scaler'
scaler = StandardScaler()

# Fitting the training data into scaler fit and transform
X_train['Amount'] = scaler.fit_transform(X_train[['Amount']])

# %%
# Obtaining the 'head' of the training dataset
X_train.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 180695  1.940609 -0.306578 -0.263310  0.478957 -0.686193 -0.736899 -0.370067
# 119122 -0.351087  1.139454  0.708544  0.896163 -0.252349 -0.487510  0.340210
# 217148  2.096140  0.065844 -2.134366  0.511475  0.661509 -0.408522 -0.003712
# 262937  2.030674 -1.170730 -0.168091 -0.424615 -1.215758  0.189006 -1.294019
# 81390   1.213965  0.017884  0.464677  0.047778 -0.594711 -0.864414 -0.074100
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 180695 -0.139161  1.165321 -0.194436  ... -0.135515 -0.157480 -0.314254
# 119122  0.388822 -0.997535 -0.222020  ... -0.069422  0.239806  0.548828
# 217148 -0.123587  0.919651 -0.666343  ... -0.154562 -0.092064  0.004436
# 262937  0.111681  0.370147  0.733121  ... -0.450583 -0.363356 -0.516502
# 81390  -0.148131 -0.171999  0.019542  ...  0.008156  0.143182  0.443130
#
# ...

# %% [markdown]
# #### SCALING & TRANSFORMING - TESTING DATA

# %% [raw]
# The testing data is not scaled to fit. It is only transformed.

# %%
# Transforming the Testing data
X_test['Amount'] = scaler.transform(X_test[['Amount']])
X_test.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 212072  1.518438 -1.679668 -3.093086 -0.388660  0.164518 -0.769884  0.859728
# 7676   -2.372834 -0.612308  3.224686  3.758968 -0.483226  1.615778 -1.719115
# 83150   1.259924  0.259231  0.516221  0.620255 -0.469781 -0.990647  0.071091
# 125745 -0.432809  0.441564  2.135267  1.571277  0.007931  1.057945 -0.090015
# 84402  -1.152360  0.039113  1.395097  0.304623  1.032487  0.037363  0.547830
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 212072 -0.480274 -1.287091  1.059841  ...  0.112677  0.133875  0.049919
# 7676    1.101559  1.853864  0.467220  ...  0.350868 -0.021965  0.630479
# 83150  -0.213189  0.025140 -0.069639  ... -0.084556 -0.255738 -0.733569
# 125745  0.405717  0.597818 -0.578365  ...  0.010397 -0.325426 -0.474865
# 84402   0.280413 -0.416573 -0.628372  ...  0.076870  0.108875  0.131383
#
# ...

# %% [markdown]
# ### CHECKING FOR SKEWNESS

# %%
# Listing the Columns
cols = X_train.columns
cols
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
# Plotting the distribution of the variables (skewness) of all the columns
k=0
plt.figure(figsize=(17,28))
for col in cols :    
    k=k+1
    plt.subplot(6,5,k)    
    sb.histplot(X_train[col], kde=True)
    plt.title(col+' '+str(round(X_train[col].skew(),2)))

plt.tight_layout()
plt.show()

# %% [markdown]
# #### MITIGATING SKEWNESS WITH POWER_TRANSFORMER

# %%
# Importing the PowerTransformer Module from Scikit Learn library.
from sklearn.preprocessing import PowerTransformer

# Setting PowerTransformer to variable 'pt'
pt = PowerTransformer(method='yeo-johnson',standardize=True,copy=False)

# Fit and Transform the PowerTransformer on the Training Data
X_train[cols] = pt.fit_transform(X_train)

# Transform the PowerTransformer on the Testing Data
X_test[cols] = pt.transform(X_test)

# %%
# Plotting the distribution of the variables (skewness) of all the columns.
k=0
plt.figure(figsize=(17,28))
for col in cols :    
    k=k+1
    plt.subplot(6,5,k)    
    sb.distplot(X_train[col])
    plt.title(col+' | Skew: '+str(round(X_train[col].skew(),2)))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### MODEL BUILDING ON IMBALANCED DATA

# %% [markdown]
# #### Metric Selection for Heavily Imbalanced Data

# %% [raw]
# The data present in the dataset is heavily imbalanced.
# Only 0.17% transctions are fraudulent.
# We should not consider Accuracy as a good measure for evaluating the model.
# Because in the case of all the datapoints return a particular class(1/0) irrespective of any prediction, still the model will result more than 99% Accuracy.
# Hence, we have to measure the ROC-AUC score for fair evaluation of the model.
# The ROC curve is used to understand the strength of the model by evaluating the performance of the model at all the classification thresholds.
# The default threshold of 0.5 is not always the ideal threshold to find the best classification label of the test point.
# Because the ROC curve is measured at all thresholds, the best threshold would be one at which the TPR is high and FPR is low, i.e., misclassifications are low.
# After determining the optimal threshold, we can calculate the F1 score of the classifier to measure the precision and recall at the selected threshold.

# %% [markdown]
# #### SVM (Support Vector Machines) Not Used for Model Building

# %% [raw]
# There are 284807 datapoints in the dataset.
# In case of Oversampling there are more number of datapoints.
# SVM is not very efficient with large number of datapoints beacuse it takes lot of computational power and resources to make the transformation.
# Perform the cross validation with K-Fold for hyperparameter tuning takes lot of computational resources and it is very time consuming.

# %% [markdown]
# #### KNN (K-Nearest Neighbour) Not Used for Model Building

# %% [raw]
# KNN is not memory efficient.
# It becomes very slow as the number of datapoints increases as the model needs to store all the data points.
# It is computationally heavy because for a single datapoint the algorithm has to calculate the distance of all the datapoints and find the nearest neighbors.

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
# Importing Logistic Regression module from Scikit Learn library
from sklearn.linear_model import LogisticRegression

# Importing Metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# %% [markdown]
# #### Tuning Hyperparameter C

# %% [raw]
# Hyperparameter C is the inverse of regularization strength in Logistic Regression.
# Higher values of C correspond to lesser regularization.

# %%
# Importing libraries for cross validation
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
# Creating KFold object with 5 splits
folds = KFold(n_splits=5,shuffle=True,random_state=4)

# Specify params
params = {"C": [0.01, 0.1, 1, 10, 100, 1000]}

# Specifing score as recall as we are more focused on acheiving the higher sensitivity than the accuracy
model_cv = GridSearchCV(estimator = LogisticRegression(),
                        param_grid = params, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True) 

# Fit the model
model_cv.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=4, shuffle=True),
#              estimator=LogisticRegression(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
# Obtaining results of grid search CV
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.402128      0.073961         0.033062        0.006379     0.01
# 1       0.499007      0.082173         0.034758        0.003896     0.10
# 2       0.582579      0.028672         0.038336        0.001328     1.00
# 3       0.601498      0.110216         0.038482        0.005721    10.00
# 4       0.398392      0.039000         0.031754        0.002841   100.00
# 5       0.456231      0.066724         0.032384        0.002507  1000.00
#
#         params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'C': 0.01}           0.984365           0.975105           0.979028
# 1   {'C': 0.1}           0.984011           0.975387           0.976924
# 2     {'C': 1}           0.983932           0.975650           0.976424
# 3    {'C': 10}           0.983916           0.975645           0.974580
# 4   {'C': 100}           0.983916           0.975721           0.974572
# ...

# %%
# Line plot of hyperparameter C Vs. Training and Testing scores
plt.figure(figsize=(8, 6))
plt.plot(cv_results['param_C'], cv_results['mean_test_score'])
plt.plot(cv_results['param_C'], cv_results['mean_train_score'])
plt.xlabel('C')
plt.ylabel('roc_auc')
plt.legend(['test result', 'train result'], loc='upper left')
plt.xscale('log')
plt.show()

# %%
# Best score with best C
best_score = model_cv.best_score_
best_C = model_cv.best_params_['C']

print(" The highest test roc_auc is {0} at C = {1}".format(best_score, best_C))
# Out:
#  The highest test roc_auc is 0.9791621892420637 at C = 0.01

# %% [markdown]
# #### Logistic Regression with Optimal C

# %%
# Assigning model with Best C to 'logistic_imb'
logistic_imb = LogisticRegression(C=0.01)

# Fit the model on the train set
logistic_imb_model = logistic_imb.fit(X_train, Y_train)

# %% [markdown]
# #### Prediction On The Training Set

# %%
# Predictions on the train set
Y_train_pred = logistic_imb_model.predict(X_train)

# %% [markdown]
# #### Creating the Confusion Matrix

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(Y_train, Y_train_pred)
print(confusion)
# Out:
# [[213203     30]
#  [   151    221]]

# %%
# Elements of the Confusion Matrix
TP = confusion[1,1] # true positives 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_train, Y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(Y_train, Y_train_pred))
# Out:
# Accuracy:- 0.999152641558016
# Sensitivity:- 0.5940860215053764
# Specificity:- 0.9998593088311847
# F1-Score:- 0.709470304975923

# %%
# Classification Report
print(classification_report(Y_train, Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    213233
#            1       0.88      0.59      0.71       372
#
#     accuracy                           1.00    213605
#    macro avg       0.94      0.80      0.85    213605
# weighted avg       1.00      1.00      1.00    213605

# %% [markdown]
# #### ROC On The Training Set

# %%
# ROC Curve function

def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
                                              drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(5, 5))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return None

# %%
# Predicted probability
Y_train_pred_proba = logistic_imb_model.predict_proba(X_train)[:,1]

# %%
# Plot the ROC curve
draw_roc(Y_train, Y_train_pred_proba)

# %% [raw]
# ROC of 0.98 has been achieved on the Training Set

# %% [markdown]
# #### Prediction on The Training Set

# %%
# Prediction on the test set
Y_test_pred = logistic_imb_model.predict(X_test)

# Confusion matrix
confusion = metrics.confusion_matrix(Y_test, Y_test_pred)
print(confusion)
# Out:
# [[71033    49]
#  [   33    87]]

# %%
# Elements of the Confusion Matrix
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_test, Y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(Y_test, Y_test_pred))
# Out:
# Accuracy:- 0.9988483469565461
# Sensitivity:- 0.725
# Specificity:- 0.9993106552995132
# F1-Score:- 0.6796875

# %%
# Classification Report
print(classification_report(Y_test, Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.64      0.72      0.68       120
#
#     accuracy                           1.00     71202
#    macro avg       0.82      0.86      0.84     71202
# weighted avg       1.00      1.00      1.00     71202

# %% [markdown]
# #### ROC On The Testing Data

# %%
# Predicted probability
Y_test_pred_proba = logistic_imb_model.predict_proba(X_test)[:,1]

# %%
# Plot the ROC curve
draw_roc(Y_test, Y_test_pred_proba)

# %% [markdown]
# ROC of 0.98 has been achieved on the Testing Data

# %% [raw]
# MODEL INFORMATION
#
# A. TRAINING DATASET
# Accuracy:- 0.99
# Sensitivity:- 0.594
# Specificity:- 0.999
# F1-Score:- 0.709
# ROC Score:- 0.98
#
# B. TESTING DATASET
# Accuracy:- 0.9988
# Sensitivity:- 0.725
# Specificity:- 0.999
# F1-Score:- 0.679
# ROC Score:- 0.98
#
# Overall, the model is performing well in the test set, what it had learnt from the train set.

# %% [markdown]
# ### XG Boost

# %%
# Importing XGBoost
# !pip install xgboost
from xgboost import XGBClassifier
# Out:
# ...
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/72.0 MB 1.3 MB/s eta 0:00:58
#    ---------------------------------------- 0.8/72.0 MB 1.2 MB/s eta 0:01:00
#     --------------------------------------- 1.0/72.0 MB 1.3 MB/s eta 0:00:55
#     --------------------------------------- 1.3/72.0 MB 1.3 MB/s eta 0:00:56
#     --------------------------------------- 1.6/72.0 MB 1.3 MB/s eta 0:00:53
#    - -------------------------------------- 1.8/72.0 MB 1.3 MB/s eta 0:00:54
#    - -------------------------------------- 2.1/72.0 MB 1.3 MB/s eta 0:00:55
#    - -------------------------------------- 2.4/72.0 MB 1.3 MB/s eta 0:00:54
#    - -------------------------------------- 2.6/72.0 MB 1.3 MB/s eta 0:00:55
# ...

# %% [markdown]
# #### Hyperparameter Tuning

# %%
# hyperparameter tuning with XGBoost

# creating a KFold object 
folds = 3

# specify range of hyperparameters
param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]}          


# specify model
xgb_model = XGBClassifier(max_depth=2, n_estimators=200)

# set up GridSearchCV()
model_cv = GridSearchCV(estimator = xgb_model, 
                        param_grid = param_grid, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True)      

# fit the model
model_cv.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
# ...

# %%
# cv results
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       1.959788      0.005946         0.048888        0.001919
# 1       1.957684      0.078055         0.048707        0.001015
# 2       3.865808      0.103133         0.057357        0.001967
# 3       4.064016      0.114669         0.056280        0.000239
# 4       3.986089      0.070638         0.056400        0.001480
# 5       3.971940      0.134076         0.056730        0.000650
#
#    param_learning_rate  param_subsample  \
# 0                  0.2              0.3
# 1                  0.2              0.6
# 2                  0.2              0.9
# 3                  0.6              0.3
# 4                  0.6              0.6
# 5                  0.6              0.9
#
#                                      params  split0_test_score  \
# 0  {'learning_rate': 0.2, 'subsample': 0.3}           0.981033
# 1  {'learning_rate': 0.2, 'subsample': 0.6}           0.974635
# ...

# %%
# Plotting
plt.figure(figsize=(16,6))

param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]} 


for n, subsample in enumerate(param_grid['subsample']):
    

    # subplot 1/n
    plt.subplot(1,len(param_grid['subsample']), n+1)
    df = cv_results[cv_results['param_subsample']==subsample]

    plt.plot(df["param_learning_rate"], df["mean_test_score"])
    plt.plot(df["param_learning_rate"], df["mean_train_score"])
    plt.xlabel('learning_rate')
    plt.ylabel('AUC')
    plt.title("subsample={0}".format(subsample))
    plt.ylim([0.60, 1])
    plt.legend(['test score', 'train score'], loc='upper left')
    plt.xscale('log')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### MODEL WITH OPTIMAL HYPERPARAMETER

# %% [raw]
# We see that the train score almost touches to 1. Among the hyperparameters, we can choose the best parameters as learning_rate : 0.2 and subsample: 0.3

# %%
model_cv.best_params_
# Out:
# {'learning_rate': 0.2, 'subsample': 0.3}

# %%
# Chosen Hyperparameters
# 'objective':'binary:logistic' outputs probability rather than label, which we need for calculating auc
params = {'learning_rate': 0.2,
          'max_depth': 2, 
          'n_estimators':200,
          'subsample':0.9,
         'objective':'binary:logistic'}

# fit model on training data
xgb_imb_model = XGBClassifier(params = params)
xgb_imb_model.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# #### Prediction On The Training Set

# %%
# Predictions on the Training Dataset
Y_train_pred = xgb_imb_model.predict(X_train)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(Y_train, Y_train_pred)
print(confusion)
# Out:
# [[213232      1]
#  [     3    369]]

# %%
# Elements of The Confusion Matrix
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_train, Y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(Y_train, Y_train_pred))
# Out:
# Accuracy:- 0.999981273846586
# Sensitivity:- 0.9919354838709677
# Specificity:- 0.9999953102943728
# F1-Score:- 0.9946091644204852

# %%
# Classification Report
print(classification_report(Y_train, Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    213233
#            1       1.00      0.99      0.99       372
#
#     accuracy                           1.00    213605
#    macro avg       1.00      1.00      1.00    213605
# weighted avg       1.00      1.00      1.00    213605

# %%
# Predicted Probability
Y_train_pred_proba_imb_xgb = xgb_imb_model.predict_proba(X_train)[:,1]

# %%
# ROC AUC
auc = f"{round(metrics.roc_auc_score(Y_train, Y_train_pred_proba_imb_xgb),4)}"
auc
# Out:
# '1.0'

# %%
# Plot the ROC curve
draw_roc(Y_train, Y_train_pred_proba_imb_xgb)

# %% [markdown]
# #### Prediction On The Testing Set

# %%
# Predictions on the test set
Y_test_pred = xgb_imb_model.predict(X_test)

# Confusion Matrix
confusion = metrics.confusion_matrix(Y_test, Y_test_pred)
print(confusion)
# Out:
# [[71060    22]
#  [   23    97]]

# %%
# Elements of the Confusion Matrix
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_test, Y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(Y_test, Y_test_pred))
# Out:
# Accuracy:- 0.9993679952810315
# Sensitivity:- 0.8083333333333333
# Specificity:- 0.9996904982977406
# F1-Score:- 0.8117154811715481

# %%
# Classification Report
print(classification_report(Y_test, Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.82      0.81      0.81       120
#
#     accuracy                           1.00     71202
#    macro avg       0.91      0.90      0.91     71202
# weighted avg       1.00      1.00      1.00     71202

# %%
# Predicted Probability
Y_test_pred_proba = xgb_imb_model.predict_proba(X_test)[:,1]

# %%
# ROC AUC
auc = f"{round(metrics.roc_auc_score(Y_test, Y_test_pred_proba),4)}"
auc
# Out:
# '0.9564'

# %%
# Plot the ROC curve
draw_roc(Y_test, Y_test_pred_proba)

# %% [markdown]
# MODEL INFORMATION
#
# A. TRAINING DATASET
# Accuracy:- 0.9999
# Sensitivity:- 0.9919
# Specificity:- 0.9999
# F1-Score:- 0.9946
# ROC Score:- 1.00
#
# B. TESTING DATASET
# Accuracy:- 0.9993
# Sensitivity:- 0.8083
# Specificity:- 0.9997
# F1-Score:- 0.8117
# ROC Score:- 0.9564
#
# Overall, the model is performing well in the test set, what it had learnt from the train set.

# %% [markdown]
# ### DECISION TREE

# %%
# Importing decision tree classifier module from Scikit Learn library.
from sklearn.tree import DecisionTreeClassifier

# %%
# Create the parameter grid 
param_grid = {
    'max_depth': range(5, 15, 5),
    'min_samples_leaf': range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
}


# Instantiate the grid search model
dtree = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dtree, 
                           param_grid = param_grid, 
                           scoring= 'roc_auc',
                           cv = 3, 
                           verbose = 1)

# Fit the grid search to the data
grid_search.fit(X_train,Y_train)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': range(5, 15, 5),
#                          'min_samples_leaf': range(50, 150, 50),
#                          'min_samples_split': range(50, 150, 50)},
#              scoring='roc_auc', verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       5.918676      0.537406         0.030521        0.000239
# 1       6.065657      0.271520         0.031619        0.006086
# 2       6.149977      0.088262         0.030555        0.001962
# 3       6.176219      0.170958         0.033221        0.000743
# 4      11.883243      0.184175         0.030659        0.001053
# 5      11.922274      0.154383         0.034626        0.003159
# 6      12.009442      0.871554         0.040936        0.004718
# 7      17.916847      1.010385         0.052902        0.001191
#
#    param_max_depth  param_min_samples_leaf  param_min_samples_split  \
# 0                5                      50                       50
# 1                5                      50                      100
# 2                5                     100                       50
# 3                5                     100                      100
# ...

# %%
# Printing the optimal sensitivity score and hyperparameters
print("Best roc_auc:-", grid_search.best_score_)
print(grid_search.best_estimator_)
# Out:
# Best roc_auc:- 0.9507285500846289
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=100,
#                        min_samples_split=100)

# %%
# Model with optimal hyperparameters
dt_imb_model = DecisionTreeClassifier(criterion = "gini", 
                                  random_state = 100,
                                  max_depth=5, 
                                  min_samples_leaf=100,
                                  min_samples_split=100)

dt_imb_model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=100, min_samples_split=100,
#                        random_state=100)

# %% [markdown]
# #### Prediction On The Training Set

# %%
# Predictions on the training dataset
Y_train_pred = dt_imb_model.predict(X_train)

# Confusion matrix
confusion = metrics.confusion_matrix(Y_train, Y_train)
print(confusion)
# Out:
# [[213233      0]
#  [     0    372]]

# %%
# Elements of the Confusion Matrix
TP = confusion[1,1] # true positives 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_train, Y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(Y_train, Y_train_pred))
# Out:
# Accuracy:- 0.9990964630977739
# Sensitivity:- 1.0
# Specificity:- 1.0
# F1-Score:- 0.6820428336079077

# %%
# Classification Report
print(classification_report(Y_train, Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    213233
#            1       0.88      0.56      0.68       372
#
#     accuracy                           1.00    213605
#    macro avg       0.94      0.78      0.84    213605
# weighted avg       1.00      1.00      1.00    213605

# %%
# Predicted Probability
Y_train_pred_proba = dt_imb_model.predict_proba(X_train)[:,1]

# %%
# ROC AUC
auc = f"{round(metrics.roc_auc_score(Y_train, Y_train_pred_proba),4)}"
auc
# Out:
# '0.9561'

# %%
# Plot the ROC curve
draw_roc(Y_train, Y_train_pred_proba)

# %% [markdown]
# #### Prediction On The Testing Set

# %%
# Predictions on the testing dataset
Y_test_pred = dt_imb_model.predict(X_test)

# Confusion Matrix
confusion = metrics.confusion_matrix(Y_test, Y_test_pred)
print(confusion)
# Out:
# [[71064    18]
#  [   48    72]]

# %%
# Elements of the Confusion Matrix
TP = confusion[1,1] # true positives 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_test, Y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(Y_train, Y_train_pred))
# Out:
# Accuracy:- 0.9990730597455127
# Sensitivity:- 0.6
# Specificity:- 0.9997467713345151
# F1-Score:- 0.6820428336079077

# %%
# Classification Report
print(classification_report(Y_test, Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.80      0.60      0.69       120
#
#     accuracy                           1.00     71202
#    macro avg       0.90      0.80      0.84     71202
# weighted avg       1.00      1.00      1.00     71202

# %%
# Predicted Probability
Y_test_pred_proba = dt_imb_model.predict_proba(X_test)[:,1]

# %%
# ROC AUC
auc = f"{round(metrics.roc_auc_score(Y_test, Y_test_pred_proba),4)}"
auc
# Out:
# '0.9523'

# %%
# Plot the ROC curve
draw_roc(Y_test, Y_test_pred_proba)

# %% [markdown]
# MODEL INFORMATION
#
# A. TRAINING DATASET
# Accuracy:- 0.9991
# Sensitivity:- 1.0
# Specificity:- 1.0
# F1-Score:- 0.682
# ROC Score:- 0.96
#
# B. TESTING DATASET
# Accuracy:- 0.999
# Sensitivity:- 0.6
# Specificity:- 0.9997
# F1-Score:- 0.682
# ROC Score:- 0.95
#
# Overall, the model is performing well in the test set, what it had learnt from the train set.

# %% [markdown]
# ### AdaSyn (Adaptive Synthetic Sampling)

# %%
# Importing Adasyn
from imblearn.over_sampling import ADASYN

# %%
# Importing undersampler library
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# %%
# Assigning adasyn to 'ada'
ada = ADASYN(random_state=0)
X_train_adasyn, Y_train_adasyn = ada.fit_resample(X_train, Y_train)

# %%
# Before sampling class distribution
print('Before sampling class distribution:-',Counter(Y_train))

# New Class Distribution 
print('New class distribution:-',Counter(Y_train_adasyn))
# Out:
# Before sampling class distribution:- Counter({0: 213233, 1: 372})
# New class distribution:- Counter({0: 213233, 1: 213228})

# %% [markdown]
# ### Logistic Regression With Optimal C

# %%
# Assigning model with best C
logistic_bal_adasyn = LogisticRegression(C=1000)

# %%
# Fit the model on the train set
logistic_bal_adasyn_model = logistic_bal_adasyn.fit(X_train_adasyn, Y_train_adasyn)

# %% [markdown]
# #### Prediction On The Training Set

# %%
# Predictions on the train set
Y_train_pred = logistic_bal_adasyn_model.predict(X_train_adasyn)

# Confusion Matrix
confusion = metrics.confusion_matrix(Y_train_adasyn, Y_train_pred)
print(confusion)
# Out:
# [[193200  20033]
#  [ 30163 183065]]

# %%
# Elements of the Confusion Matrix
TP = confusion[1,1] # true positives 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_train_adasyn, Y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(Y_train_adasyn, Y_train_pred))
# Out:
# Accuracy:- 0.8822963881808653
# Sensitivity:- 0.8585410921642561
# Specificity:- 0.9060511271707475
# F1-Score:- 0.8794310228042448

# %%
# Classification Report
print(classification_report(Y_train_adasyn, Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.89    213233
#            1       0.90      0.86      0.88    213228
#
#     accuracy                           0.88    426461
#    macro avg       0.88      0.88      0.88    426461
# weighted avg       0.88      0.88      0.88    426461

# %%
# Predicted Probability
Y_train_pred_proba = logistic_bal_adasyn_model.predict_proba(X_train_adasyn)[:,1]

# %%
# ROC auc
auc = f"{round(metrics.roc_auc_score(Y_train_adasyn, Y_train_pred_proba),4)}"
auc
# Out:
# '0.9605'

# %%
# Plot the ROC curve
draw_roc(Y_train_adasyn, Y_train_pred_proba)

# %% [markdown]
# #### Prediction On The Testing Set

# %%
# Prediction on the test set
Y_test_pred = logistic_bal_adasyn_model.predict(X_test)

# Confusion Matrix
confusion = metrics.confusion_matrix(Y_test, Y_test_pred)
print(confusion)
# Out:
# [[61077 10005]
#  [    4   116]]

# %%
# Elements of the Confusion matrix
TP = confusion[1,1] # true positives 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_test, Y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.85942810595208
# Sensitivity:- 0.9666666666666667
# Specificity:- 0.8592470667679581

# %%
# Classification Report
print(classification_report(Y_test, Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92     71082
#            1       0.01      0.97      0.02       120
#
#     accuracy                           0.86     71202
#    macro avg       0.51      0.91      0.47     71202
# weighted avg       1.00      0.86      0.92     71202

# %%
# Predicted Probability
Y_test_pred_proba = logistic_bal_adasyn_model.predict_proba(X_test)[:,1]

# ROC AUC
auc = f"{round(metrics.roc_auc_score(Y_test, Y_test_pred_proba),4)}"
auc
# Out:
# '0.9841'

# %%
# Plot the ROC curve
draw_roc(Y_test, Y_test_pred_proba)

# %% [markdown]
# MODEL SUMMARY
#
# Train set
# Accuracy = 0.8823
# Sensitivity = 0.8585
# Specificity = 0.906
# ROC = 0.96
#
# Test set
# Accuracy = 0.856
# Sensitivity = 0.967
# Specificity = 0.86
# ROC = 0.98

# %% [markdown]
# ### DECISION TREE

# %%
# Create the parameter grid 
param_grid = {
    'max_depth': range(5, 15, 5),
    'min_samples_leaf': range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
}


# Instantiate the grid search model
dtree = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dtree, 
                           param_grid = param_grid, 
                           scoring= 'roc_auc',
                           cv = 3, 
                           verbose = 1)

# Fit the grid search to the data
grid_search.fit(X_train_adasyn,Y_train_adasyn)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': range(5, 15, 5),
#                          'min_samples_leaf': range(50, 150, 50),
#                          'min_samples_split': range(50, 150, 50)},
#              scoring='roc_auc', verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      19.325694      0.328358         0.111942        0.002464
# 1      18.676170      0.250262         0.104674        0.000919
# 2      18.612827      0.085979         0.104777        0.005855
# 3      19.234900      0.592471         0.118755        0.009414
# 4      32.316656      0.068773         0.115640        0.002875
# 5      31.838292      1.063749         0.122958        0.014181
# 6      33.534509      0.641311         0.113227        0.002957
# 7      31.279204      0.532035         0.109550        0.002665
#
#    param_max_depth  param_min_samples_leaf  param_min_samples_split  \
# 0                5                      50                       50
# 1                5                      50                      100
# 2                5                     100                       50
# 3                5                     100                      100
# ...

# %%
# Printing the optimal sensitivity score and hyperparameters
print("Best roc_auc:-", grid_search.best_score_)
print(grid_search.best_estimator_)
# Out:
# Best roc_auc:- 0.9523924584068761
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=100, min_samples_split=50)

# %%
# Model with optimal hyperparameters
dt_bal_adasyn_model = DecisionTreeClassifier(criterion = "gini", 
                                  random_state = 100,
                                  max_depth=10, 
                                  min_samples_leaf=100,
                                  min_samples_split=50)

dt_bal_adasyn_model.fit(X_train_adasyn, Y_train_adasyn)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=100, min_samples_split=50,
#                        random_state=100)

# %% [markdown]
# #### Prediction On The Training Dataset

# %%
# Predictions on the train set
Y_train_pred = dt_bal_adasyn_model.predict(X_train_adasyn)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(Y_train_adasyn, Y_train_pred)
print(confusion)
# Out:
# [[206635   6598]
#  [  1283 211945]]

# %%
# Elements of the Confusion matrix
TP = confusion[1,1] # true positives 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_train_adasyn, Y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9815199983116861
# Sensitivity:- 0.9939829665897537
# Specificity:- 0.969057322271881

# %%
# Classification Report
print(classification_report(Y_train_adasyn, Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98    213233
#            1       0.97      0.99      0.98    213228
#
#     accuracy                           0.98    426461
#    macro avg       0.98      0.98      0.98    426461
# weighted avg       0.98      0.98      0.98    426461

# %%
# Predicted Probability
Y_train_pred_proba = dt_bal_adasyn_model.predict_proba(X_train_adasyn)[:,1]

# %%
# roc_auc
auc = f"{round(metrics.roc_auc_score(Y_train_adasyn, Y_train_pred_proba),4)}"
auc
# Out:
# '0.9928'

# %%
# Plot the ROC curve
draw_roc(Y_train_adasyn, Y_train_pred_proba)

# %% [markdown]
# #### Prediction On The Testing Dataset

# %%
# Predictions on the test set
Y_test_pred = dt_bal_adasyn_model.predict(X_test)

# Confusion Matrix
confusion = metrics.confusion_matrix(Y_test, Y_test_pred)
print(confusion)
# Out:
# [[69242  1840]
#  [   14   106]]

# %%
# Elements of the Confusion Matrix
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_test, Y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.973961405578495
# Sensitivity:- 0.8833333333333333
# Specificity:- 0.9741144030837624

# %%
# Classification Report
print(classification_report(Y_test, Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     71082
#            1       0.05      0.88      0.10       120
#
#     accuracy                           0.97     71202
#    macro avg       0.53      0.93      0.54     71202
# weighted avg       1.00      0.97      0.99     71202

# %%
# Predicted probability
Y_test_pred_proba = dt_bal_adasyn_model.predict_proba(X_test)[:,1]

# %%
# ROC AUC
auc = f"{round(metrics.roc_auc_score(Y_test, Y_test_pred_proba),4)}"
auc
# Out:
# '0.94'

# %%
# Plot the ROC curve
draw_roc(Y_test, Y_test_pred_proba)

# %% [raw]
# MODEL SUMMARY
#
# Training Dataset
# Accuracy:- 0.98152
# Sensitivity:- 0.994
# Specificity:- 0.969
# ROC:- 0.99
#
# Testing Dataset
# Accuracy:- 0.974
# Sensitivity:- 0.883
# Specificity:- 0.974
# ROC:- 0.94

# %% [markdown]
# ### XG BOOST

# %%
# hyperparameter tuning with XGBoost

# creating a KFold object 
folds = 3

# specify range of hyperparameters
param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]}          


# specify model
xgb_model = XGBClassifier(max_depth=2, n_estimators=200)

# set up GridSearchCV()
model_cv = GridSearchCV(estimator = xgb_model, 
                        param_grid = param_grid, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True)      

# fit the model
model_cv.fit(X_train_adasyn, Y_train_adasyn)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
# ...

# %%
# cv results
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.847795      0.054469         0.097667        0.006793
# 1       2.891768      0.106663         0.092763        0.001478
# 2       2.852703      0.081480         0.094412        0.003060
# 3       2.816405      0.065390         0.090113        0.000888
# 4       2.942331      0.076019         0.095842        0.004310
# 5       2.752376      0.025796         0.093913        0.001199
#
#    param_learning_rate  param_subsample  \
# 0                  0.2              0.3
# 1                  0.2              0.6
# 2                  0.2              0.9
# 3                  0.6              0.3
# 4                  0.6              0.6
# 5                  0.6              0.9
#
#                                      params  split0_test_score  \
# 0  {'learning_rate': 0.2, 'subsample': 0.3}           0.986998
# 1  {'learning_rate': 0.2, 'subsample': 0.6}           0.987784
# ...

# %%
# plotting
plt.figure(figsize=(16,6))

param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]} 


for n, subsample in enumerate(param_grid['subsample']):
    

    # subplot 1/n
    plt.subplot(1,len(param_grid['subsample']), n+1)
    df = cv_results[cv_results['param_subsample']==subsample]

    plt.plot(df["param_learning_rate"], df["mean_test_score"])
    plt.plot(df["param_learning_rate"], df["mean_train_score"])
    plt.xlabel('learning_rate')
    plt.ylabel('AUC')
    plt.title("subsample={0}".format(subsample))
    plt.ylim([0.60, 1])
    plt.legend(['test score', 'train score'], loc='upper left')
    plt.xscale('log')

plt.tight_layout()
plt.show()

# %%
model_cv.best_params_
# Out:
# {'learning_rate': 0.6, 'subsample': 0.3}

# %%
# chosen hyperparameters

params = {'learning_rate': 0.6,
          'max_depth': 2, 
          'n_estimators':200,
          'subsample':0.3,
         'objective':'binary:logistic'}

# fit model on training data
xgb_bal_adasyn_model = XGBClassifier(params = params)
xgb_bal_adasyn_model.fit(X_train_adasyn, Y_train_adasyn)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# #### Prediction On The Training Dataset

# %%
# Predictions on the train set
Y_train_pred = xgb_bal_adasyn_model.predict(X_train_adasyn)

# Confusion Matrix
confusion = metrics.confusion_matrix(Y_train_adasyn, Y_train_adasyn)
print(confusion)
# Out:
# [[213233      0]
#  [     0 213228]]

# %%
# Elements of the Confusion Matrix
TP = confusion[1,1] # true positives 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_train_adasyn, Y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9999929653590832
# Sensitivity:- 1.0
# Specificity:- 1.0

# %%
# Classification Report
print(classification_report(Y_train_adasyn, Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    213233
#            1       1.00      1.00      1.00    213228
#
#     accuracy                           1.00    426461
#    macro avg       1.00      1.00      1.00    426461
# weighted avg       1.00      1.00      1.00    426461

# %%
# Predicted Probability
Y_train_pred_proba = xgb_bal_adasyn_model.predict_proba(X_train_adasyn)[:,1]

# ROC AUC
auc = f"{round(metrics.roc_auc_score(Y_train_adasyn, Y_train_pred_proba),4)}"
auc
# Out:
# '1.0'

# %%
# Plot the ROC curve
draw_roc(Y_train_adasyn, Y_train_pred_proba)

# %% [markdown]
# #### Prediction On The Testing Dataset

# %%
# Predictions on the Testing Dataset
Y_test_pred = xgb_bal_adasyn_model.predict(X_test)

# Confusion Matrix
confusion = metrics.confusion_matrix(Y_test, Y_test_pred)
print(confusion)
# Out:
# [[70913   169]
#  [   16   104]]

# %%
# Elements of the Confusion Matrix
TP = confusion[1,1] # true positives 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_test, Y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9974017583775736
# Sensitivity:- 0.8666666666666667
# Specificity:- 0.9976224641962803

# %%
# Classification Report
print(classification_report(Y_test, Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.38      0.87      0.53       120
#
#     accuracy                           1.00     71202
#    macro avg       0.69      0.93      0.76     71202
# weighted avg       1.00      1.00      1.00     71202

# %%
# Predicted probability
Y_test_pred_proba = xgb_bal_adasyn_model.predict_proba(X_test)[:,1]

# ROC AUC
auc = f"{round(metrics.roc_auc_score(Y_test, Y_test_pred_proba),4)}"
auc
# Out:
# '0.9811'

# %%
# Plot the ROC curve
draw_roc(Y_test, Y_test_pred_proba)

# %% [markdown]
# MODEL SUMMARY
#
# Training Dataset
# Accuracy:- 0.9999
# Sensitivity:- 1.0
# Specificity:- 1.0
# ROC:- 1.0
#
# Testing Dataset
# Accuracy:- 0.9974
# Sensitivity:- 0.8667
# Specificity:- 0.9976
# ROC:- 0.98

# %% [markdown]
# ### CHOOSE BEST MODEL BASED ON MODEL DATA

# %% [raw]
# 1. He we balanced the data with various approach such as Undersampling, Oversampling, SMOTE and Adasy.
# 2. With every data balancing thechnique we built several models such as Logistic, XGBoost, Decision Tree, and Random Forest.
# 3. We can see that almost all the models performed more or less good. But we should be interested in the best model.
# 4. Though the Undersampling technique models performed well, we should keep mind that by doing the undersampling some imformation were lost.
# 5. Hence, it is better not to consider the undersampling models.
# 6. Whereas the SMOTE and Adasyn models performed well. Among those models the simplist model Logistic regression has ROC score 0.99 in the train set and 0.97 on the test set.
# 7. We can consider the Logistic model as the best model to choose because of the easy interpretation of the models and also the resourse requirements to build the mdoel is lesser than the other heavy models such as Random forest or XGBoost.
# 8. Hence, we can conclude that the Logistic regression model with SMOTE is the best model for its simlicity and less resource requirement.

# %% [markdown]
# #### Printing the FPR,TPR & select the best threshold from the roc curve for the best model

# %%
print('Train auc =', metrics.roc_auc_score(Y_test, Y_test_pred))
fpr, tpr, thresholds = metrics.roc_curve(Y_test, Y_test_pred)
threshold = thresholds[np.argmax(tpr-fpr)]
print("Threshold=",threshold)
# Out:
# Train auc = 0.9321445654314735
# Threshold= 1.0

# %% [markdown]
# ### COST BENEFIT ANALYSIS

# %% [raw]
# 1. Having tried several models till now with both balanced and imbalanced data.
# 2. We have noticed most of the models have performed more or less well in terms of ROC score, Precision and Recall.
# 3. But while picking the best model we should consider few things such as whether we have required infrastructure, resources or computational power to run the model or not.
# 4. For the models such as Random forest, SVM, XGBoost we require heavy computational resources and eventually to build that infrastructure the cost of deploying the model increases.
# 5. On the other hand the simpler model such as Logistic regression requires less computational resources, so the cost of building the model is less.
# 6. We have to consider that for little change of the ROC score how much monetary loss of gain the bank incurs.
# 7. If the amount if huge then we have to consider building the complex model even though the cost of building the model is high.

# %% [markdown]
# ### SUMMARY OF THE BUSINESS

# %% [raw]
# For banks with smaller average transaction value, we would want high precision because we only want to label relevant transactions as fraudulent.
# For every transaction that is flagged as fraudulent, we can add the human element to verify whether the transaction was done by calling the customer. However, when precision is low, such tasks are a burden because the human element has to be increased.
#
# For banks having a larger transaction value, if the recall is low, i.e., it is unable to detect transactions that are labelled as non-fraudulent.
# So we have to consider the losses if the missed transaction was a high-value fraudulent one.
#
# So here, to save the banks from high-value fraudulent transactions, we have to focus on a high recall in order to detect actual fraudulent transactions.
#
# After performing several models, we have seen that in the balanced dataset with ADASYN technique with the simplest Logistic regression model has good ROC score and also high Recall.
# Hence, we can go with the logistic model here. It is also easier to interpret and explain to the business.
